# %%
import cv2
from fer import FER
import matplotlib.pyplot as plt

# %%
input_image = cv2.imread("images/1.jpg")
input_image=cv2.cvtColor(input_image,cv2.COLOR_BGR2RGB)
plt.imshow(input_image)

# %%
emotion_detector = FER()
result = emotion_detector.detect_emotions(input_image)

# %%
box=result[0]["box"]
cv2.rectangle(input_image,(box[0],box[1]),(box[0]+box[2],box[1]+box[3]),(255,0,0),2)
plt.imshow(input_image)

# %%
plt.imshow(input_image)
plt.show()
emotions=result[0]["emotions"]
for index, (emotion_name, score) in enumerate(emotions.items()):
    emotion_score = "{}: {}".format(emotion_name, "{:.2f}".format(score))
    print(emotion_score)
# Out:
# angry: 0.00
# disgust: 0.00
# fear: 0.00
# happy: 0.99
# sad: 0.00
# surprise: 0.00
# neutral: 0.01
